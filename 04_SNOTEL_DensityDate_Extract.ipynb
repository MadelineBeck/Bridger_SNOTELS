# %%
import pandas as pd
from pandas import read_csv
import glob

# %%
# Read in the Brackett dataframe
brackett_df = read_csv('/Users/f67f911/Desktop/Bridger_snotels/Data/Site_Data/Brackett_export.csv', header=0, index_col=0)
brackett_df
# Out:
#                            Daily Precipitation (in)  Daily Snow Depth (in)  \
# datetime
# 1994-09-29 00:00:00+00:00                       NaN                    NaN
# 1994-09-30 00:00:00+00:00                       NaN                    NaN
# 1994-10-01 00:00:00+00:00                       0.5                    NaN
# 1994-10-02 00:00:00+00:00                       0.0                    NaN
# 1994-10-03 00:00:00+00:00                       0.1                    NaN
# ...                                             ...                    ...
# 2022-09-22 00:00:00+00:00                       1.7                    0.0
# 2022-09-23 00:00:00+00:00                       0.1                    0.0
# 2022-09-24 00:00:00+00:00                       0.1                    0.0
# 2022-09-25 00:00:00+00:00                       0.0                    0.0
# 2022-09-26 00:00:00+00:00                       NaN                    0.0
#
# ...

# %%
# Set the datetime column to a datetime and make it the index
brackett_df.index = pd.to_datetime(brackett_df.index)

# %%
# Read in the sacajawea data
sac_df = read_csv('/Users/f67f911/Desktop/Bridger_snotels/Data/Site_Data/Sacajawea_export.csv', header=0, index_col=0)
sac_df
# Out:
#                            Daily Precipitation (in)  Daily Snow Depth (in)  \
# datetime
# 1999-09-30 00:00:00+00:00                       NaN                    NaN
# 1999-10-01 00:00:00+00:00                       0.0                    NaN
# 1999-10-02 00:00:00+00:00                       0.0                    NaN
# 1999-10-03 00:00:00+00:00                       0.0                    NaN
# 1999-10-04 00:00:00+00:00                       0.0                    NaN
# ...                                             ...                    ...
# 2022-09-22 00:00:00+00:00                       1.6                    0.0
# 2022-09-23 00:00:00+00:00                       0.0                    0.0
# 2022-09-24 00:00:00+00:00                       0.0                    0.0
# 2022-09-25 00:00:00+00:00                       0.0                    0.0
# 2022-09-26 00:00:00+00:00                       NaN                    0.0
#
# ...

# %%
# Set the index like the brackett data
sac_df.index = pd.to_datetime(sac_df.index)
sac_df
# Out:
#                            Daily Precipitation (in)  Daily Snow Depth (in)  \
# datetime
# 1999-09-30 00:00:00+00:00                       NaN                    NaN
# 1999-10-01 00:00:00+00:00                       0.0                    NaN
# 1999-10-02 00:00:00+00:00                       0.0                    NaN
# 1999-10-03 00:00:00+00:00                       0.0                    NaN
# 1999-10-04 00:00:00+00:00                       0.0                    NaN
# ...                                             ...                    ...
# 2022-09-22 00:00:00+00:00                       1.6                    0.0
# 2022-09-23 00:00:00+00:00                       0.0                    0.0
# 2022-09-24 00:00:00+00:00                       0.0                    0.0
# 2022-09-25 00:00:00+00:00                       0.0                    0.0
# 2022-09-26 00:00:00+00:00                       NaN                    0.0
#
# ...

# %%
# Calculate Density
brackett_df['Density %'] = brackett_df['Daily Water Equivalent (in)'] / brackett_df['Daily Snow Depth (in)']
sac_df['Density %'] = sac_df['Daily Water Equivalent (in)'] / sac_df['Daily Snow Depth (in)']

# %% [markdown]
# ## Now, extract the data for each flight date

# %%
brackett_season = brackett_df.loc[['2021-11-24','2022-01-09','2022-02-12','2022-02-18','2022-03-25','2022-04-07',
                                  '2022-05-05','2022-05-10','2022-05-17']]
brackett_season = brackett_season.reset_index()
brackett_season['station'] = 'Brackett'
brackett_season
# Out:
#                    datetime  Daily Precipitation (in)  Daily Snow Depth (in)  \
# 0 2021-11-24 00:00:00+00:00                       0.1                   12.0
# 1 2022-01-09 00:00:00+00:00                       0.0                   32.0
# 2 2022-02-12 00:00:00+00:00                       0.1                   34.0
# 3 2022-02-18 00:00:00+00:00                       0.1                   38.0
# 4 2022-03-25 00:00:00+00:00                       0.0                   42.0
# 5 2022-04-07 00:00:00+00:00                       0.1                   41.0
# 6 2022-05-05 00:00:00+00:00                       0.0                   44.0
# 7 2022-05-10 00:00:00+00:00                       0.0                   43.0
# 8 2022-05-17 00:00:00+00:00                       0.1                   35.0
#
#    Daily Average Temperature (F)  Daily Maximum Temperature (F)  \
# 0                          24.08                          28.58
# 1                          27.32                          37.40
# ...

# %%
sac_season = sac_df.loc[['2021-11-24','2022-01-09','2022-02-12','2022-02-18','2022-03-25','2022-04-07',
                                  '2022-05-05','2022-05-10','2022-05-17']]
sac_season = sac_season.reset_index()
sac_season['station'] = 'Sacajawea'
sac_season
# Out:
#                    datetime  Daily Precipitation (in)  Daily Snow Depth (in)  \
# 0 2021-11-24 00:00:00+00:00                       0.1                    2.0
# 1 2022-01-09 00:00:00+00:00                       0.0                   17.0
# 2 2022-02-12 00:00:00+00:00                       0.1                   19.0
# 3 2022-02-18 00:00:00+00:00                       0.1                   24.0
# 4 2022-03-25 00:00:00+00:00                       0.0                   22.0
# 5 2022-04-07 00:00:00+00:00                       0.1                   16.0
# 6 2022-05-05 00:00:00+00:00                       0.0                    9.0
# 7 2022-05-10 00:00:00+00:00                       0.0                    5.0
# 8 2022-05-17 00:00:00+00:00                       0.0                    0.0
#
#    Daily Average Temperature (F)  Daily Maximum Temperature (F)  \
# 0                          27.86                          31.10
# 1                          28.58                          37.04
# ...

# %%
test = pd.concat(brackett_season,sac_season,join = 'outer')
test
# Out:
# /var/folders/1h/qds9mkm123b7fhmghg50vg6w62xq56/T/ipykernel_25819/646665453.py:1: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   test = pd.concat(brackett_season,sac_season,join = 'outer')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/1h/qds9mkm123b7fhmghg50vg6w62xq56/T/ipykernel_25819/646665453.py in <module>
# ----> 1 test = pd.concat(brackett_season,sac_season,join = 'outer')
#       2 test
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
brac_season_df = pd.melt(brackett_season,id_vars = ['datetime'],value_vars = ['Density %'])
brac_season_df
# Out:
#                    datetime   variable     value
# 0 2021-11-24 00:00:00+00:00  Density %  0.250000
# 1 2022-01-09 00:00:00+00:00  Density %  0.256250
# 2 2022-02-12 00:00:00+00:00  Density %  0.297059
# 3 2022-02-18 00:00:00+00:00  Density %  0.281579
# 4 2022-03-25 00:00:00+00:00  Density %  0.350000
# 5 2022-04-07 00:00:00+00:00  Density %  0.370732
# 6 2022-05-05 00:00:00+00:00  Density %  0.388636
# 7 2022-05-10 00:00:00+00:00  Density %  0.386047
# 8 2022-05-17 00:00:00+00:00  Density %  0.408571

# %%
Nov24_Brackett = brackett_df.loc[['2021-11-24']]
Nov24_Brackett
# Out:
#                            Daily Precipitation (in)  Daily Snow Depth (in)
# datetime
# 2021-11-24 00:00:00+00:00                       0.1                   12.0  \
#
#                            Daily Average Temperature (F)
# datetime
# 2021-11-24 00:00:00+00:00                          24.08  \
#
#                            Daily Maximum Temperature (F)
# datetime
# 2021-11-24 00:00:00+00:00                          28.58  \
#
#                            Daily Minimum Temperature (F)
# datetime
# 2021-11-24 00:00:00+00:00                          21.74  \
#
#                            Daily Water Equivalent (in)  Density %
# datetime
# 2021-11-24 00:00:00+00:00                          3.0       0.25

# %%
print(type(Nov24_Brackett))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# Out:
#                            Daily Precipitation (in)  Daily Snow Depth (in)
# datetime
# 2021-01-09 00:00:00+00:00                       0.0                   19.0  \
#
#                            Daily Average Temperature (F)
# datetime
# 2021-01-09 00:00:00+00:00                          15.98  \
#
#                            Daily Maximum Temperature (F)
# datetime
# 2021-01-09 00:00:00+00:00                          30.02  \
#
#                            Daily Minimum Temperature (F)
# datetime
# 2021-01-09 00:00:00+00:00                           10.4  \
#
#                            Daily Water Equivalent (in)  Density %
# datetime
# 2021-01-09 00:00:00+00:00                          4.4   0.231579

# %%
Jan24_sac = sac_df.loc[['2022-01-24']]
Jan24_sac
# Out:
#                            Daily Precipitation (in)  Daily Snow Depth (in)
# datetime
# 2022-01-24 00:00:00+00:00                       0.1                   19.0  \
#
#                            Daily Average Temperature (F)
# datetime
# 2022-01-24 00:00:00+00:00                           27.5  \
#
#                            Daily Maximum Temperature (F)
# datetime
# 2022-01-24 00:00:00+00:00                          33.44  \
#
#                            Daily Minimum Temperature (F)
# datetime
# 2022-01-24 00:00:00+00:00                          19.76  \
#
#                            Daily Water Equivalent (in)  Density %
# datetime
# 2022-01-24 00:00:00+00:00                          5.1   0.268421

# %%
Feb12_sac = sac_df.loc[['2022-02-12']]
Feb12_sac
# Out:
#                            Daily Precipitation (in)  Daily Snow Depth (in)
# datetime
# 2022-02-12 00:00:00+00:00                       0.1                   19.0  \
#
#                            Daily Average Temperature (F)
# datetime
# 2022-02-12 00:00:00+00:00                           34.7  \
#
#                            Daily Maximum Temperature (F)
# datetime
# 2022-02-12 00:00:00+00:00                          40.46  \
#
#                            Daily Minimum Temperature (F)
# datetime
# 2022-02-12 00:00:00+00:00                          20.84  \
#
#                            Daily Water Equivalent (in)  Density %
# datetime
# 2022-02-12 00:00:00+00:00                          5.4   0.284211

# %%
Feb18_sac = sac_df.loc[['2022-02-18']]
Feb18_sac
# Out:
#                            Daily Precipitation (in)  Daily Snow Depth (in)
# datetime
# 2022-02-18 00:00:00+00:00                       0.1                   24.0  \
#
#                            Daily Average Temperature (F)
# datetime
# 2022-02-18 00:00:00+00:00                          34.16  \
#
#                            Daily Maximum Temperature (F)
# datetime
# 2022-02-18 00:00:00+00:00                          36.86  \
#
#                            Daily Minimum Temperature (F)
# datetime
# 2022-02-18 00:00:00+00:00                          30.38  \
#
#                            Daily Water Equivalent (in)  Density %
# datetime
# 2022-02-18 00:00:00+00:00                          6.0       0.25

# %%
Mar25_sac = sac_df.loc[['2022-03-25']]
Mar25_sac
# Out:
#                            Daily Precipitation (in)  Daily Snow Depth (in)
# datetime
# 2022-03-25 00:00:00+00:00                       0.0                   22.0  \
#
#                            Daily Average Temperature (F)
# datetime
# 2022-03-25 00:00:00+00:00                          36.68  \
#
#                            Daily Maximum Temperature (F)
# datetime
# 2022-03-25 00:00:00+00:00                          52.16  \
#
#                            Daily Minimum Temperature (F)
# datetime
# 2022-03-25 00:00:00+00:00                          21.92  \
#
#                            Daily Water Equivalent (in)  Density %
# datetime
# 2022-03-25 00:00:00+00:00                          7.2   0.327273

# %%
Apr07_sac = sac_df.loc[['2022-04-07']]
Apr07_sac
# Out:
#                            Daily Precipitation (in)  Daily Snow Depth (in)
# datetime
# 2022-04-07 00:00:00+00:00                       0.1                   16.0  \
#
#                            Daily Average Temperature (F)
# datetime
# 2022-04-07 00:00:00+00:00                          38.12  \
#
#                            Daily Maximum Temperature (F)
# datetime
# 2022-04-07 00:00:00+00:00                          51.44  \
#
#                            Daily Minimum Temperature (F)
# datetime
# 2022-04-07 00:00:00+00:00                          19.04  \
#
#                            Daily Water Equivalent (in)  Density %
# datetime
# 2022-04-07 00:00:00+00:00                          6.4        0.4

# %%
May05_sac = sac_df.loc[['2022-05-05']]
May05_sac
# Out:
#                            Daily Precipitation (in)  Daily Snow Depth (in)
# datetime
# 2022-05-05 00:00:00+00:00                       0.0                    9.0  \
#
#                            Daily Average Temperature (F)
# datetime
# 2022-05-05 00:00:00+00:00                          51.98  \
#
#                            Daily Maximum Temperature (F)
# datetime
# 2022-05-05 00:00:00+00:00                          65.84  \
#
#                            Daily Minimum Temperature (F)
# datetime
# 2022-05-05 00:00:00+00:00                          37.58  \
#
#                            Daily Water Equivalent (in)  Density %
# datetime
# 2022-05-05 00:00:00+00:00                          4.3   0.477778

# %%
May10_sac = sac_df.loc[['2022-05-10']]
May10_sac
# Out:
#                            Daily Precipitation (in)  Daily Snow Depth (in)
# datetime
# 2022-05-10 00:00:00+00:00                       0.0                    5.0  \
#
#                            Daily Average Temperature (F)
# datetime
# 2022-05-10 00:00:00+00:00                           35.6  \
#
#                            Daily Maximum Temperature (F)
# datetime
# 2022-05-10 00:00:00+00:00                           46.4  \
#
#                            Daily Minimum Temperature (F)
# datetime
# 2022-05-10 00:00:00+00:00                          26.42  \
#
#                            Daily Water Equivalent (in)  Density %
# datetime
# 2022-05-10 00:00:00+00:00                          3.0        0.6

# %%
May17_sac = sac_df.loc[['2022-05-17']]
May17_sac
# Out:
#                            Daily Precipitation (in)  Daily Snow Depth (in)
# datetime
# 2022-05-17 00:00:00+00:00                       0.0                    0.0  \
#
#                            Daily Average Temperature (F)
# datetime
# 2022-05-17 00:00:00+00:00                          46.58  \
#
#                            Daily Maximum Temperature (F)
# datetime
# 2022-05-17 00:00:00+00:00                          59.72  \
#
#                            Daily Minimum Temperature (F)
# datetime
# 2022-05-17 00:00:00+00:00                          35.96  \
#
#                            Daily Water Equivalent (in)  Density %
# datetime
# 2022-05-17 00:00:00+00:00                          0.0        NaN

# %%
dates = [['Nov24_Brackett','Jan09_Brackett','Jan24_Brackett','Feb12_Brackett','Feb18_Brackett',
         'Mar25_Brackett','Apr07_Brackett','May05_Brackett','May10_Brackett','May17_Brackett']]
